# %%
import pandas as pd
df = pd.read_csv('..\data\홀베리_reviews.csv')
df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\user\AppData\Local\Temp\ipykernel_22396\4208470829.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('..\data\홀베리_reviews.csv')
#              ID  RATE     CREATED  \
# 0   subr*******     5  2024-10-03
# 1  shin********     5  2024-10-04
# 2      shsh****     5  2024-10-12
# 3      jils****     5  2024-10-14
# 4      irom****     5  2024-10-12
#
#                                               REVIEW
# 0  한달사용기8월25일(일) 주문~27일(화) 배송완료.\n원체 이 제품을 선호 하는지...
# 1  레몬의 효능을 검색해 보니 면역력강화, 항산화작용, 소화건강개선, 체중관리, 피부건...
# 2  요즘 계속 먹고있는 레몬즙입니다. 첨엔 홈쇼핑에서 샀는데 지인추천으로 여기서 저렴하...
# 3  요즘 핫한 레몬즙 ^^ 우리 가족 식사때 꼭 주구요 운동할때 맹물만 마셨는데 500...
# 4  엄마가 잘 드셔서 또 주문했습니다~\n저도 먹어보니 액이 진해서 물통(500ML)에...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=500, stop_words='english')
dtm = cv.fit_transform(df['REVIEW'])
cv.get_feature_names_out()
# Out:
# array(['1일', '1포씩', '3번째', '500미리에', '6박스', 'ㅋㅋ', 'ㅎㅎ', 'ㅎㅎㅎ', 'ㅠㅠ', '가격',
#        '가격도', '가격에', '가격은', '가격이', '가장', '가지고', '간편하게', '간편하고', '간편해서',
#        '감사합니다', '강하지', '갖고', '같고', '같네요', '같습니다', '같아', '같아서', '같아요',
#        '같은데', '같이', '건강', '건강에', '건강에도', '건강을', '건강하게', '건강한', '건강해지는',
#        '계속', '공복에', '광고', '괜찮고', '괜찮네요', '괜찮습니다', '괜찮아서', '괜찮아요', '구매',
#        '구매입니다', '구매하게', '구매합니다', '구매해봤어요', '구매해서', '구매했는데', '구매했습니다',
#        '구매했어요', '구입', '구입했는데', '구입했습니다', '구입했어요', '귀찮았는데', '그냥', '그대로',
#        '그래도', '그래서', '그런지', '그리고', '근데', '금방', '기분이', '깔끔하게', '깔끔하고',
#        '껍질까지', '꼼꼼하게', '꼼꼼하고', '꾸준하게', '꾸준히', '나와서', '너무', '너무너무너무',
#        '너무좋아요', '넉넉하고', '넉넉합니다', '넉넉해서', '넣고', '넣어', '넣어서', '느낌', '느낌이',
#        '느낌이예요', '느낌입니다', '다니기', '다니기도', '다니면서', '다른', '다른곳보다', '다시',
#        '다음에', '다이어트', '다이어트에', '달지', '덕분에', '도움이', '되고', '되네요', '되는',
#        '되니', '되어', '두번째', '드시고', '들어요', '듭니다', '등등', '디톡스', '레몬', '레몬맛',
#        '레몬맛이', '레몬수', '레몬수가', '레몬수로', '레몬수를', '레몬을', '레몬이', '레몬즙', '레몬즙을',
#        '레몬즙이', '레몬즙이라', '마셔요', '마시게', '마시고', '마시고있어요', '마시기', '마시는게',
#        '마시는데', '마시니', '마시려고', '마시면', '마실', '마십니다', '마음에', '만들어', '만족',
#        '만족합니다', '만족해요', '많이', '많이파세요', '맘에', '맛나요', '맛도', '맛도좋고', '맛은',
#        '맛이', '맛이예요', '맛있게', '맛있고', '맛있네요', '맛있다고', '맛있습니다', '맛있어요', '매번',
#        '매우', '매일', '매일매일', '먹게되네요', '먹겠습니다', '먹고', '먹고있는데', '먹고있습니다',
#        '먹고있어요', '먹기', '먹기가', '먹기도', '먹기좋고', '먹기편하고', '먹기편해요', '먹는', '먹는게',
#        '먹는데', '먹다가', '먹다보니', '먹던', '먹던거라', '먹습니다', '먹어', '먹어도', '먹어보겠습니다',
#        '먹어보고', '먹어보니', '먹어보려고', '먹어보려고요', '먹어보려구요', '먹어보려합니다', '먹어볼게요',
#        '먹어볼께요', '먹어봐야', '먹어봤는데', '먹어서', '먹어요', '먹었는데', '먹었더니', '먹었어요',
#        '먹으니', '먹으니까', '먹으려고', '먹으려구요', '먹으면', '먹을', '먹을게요', '먹을만',
#        '먹을만해요', '먹을수', '모두', '모르겠어요', '모르겠지만', '몸도', '몸에', '몸에도', '몸이',
#        '물도', '물에', '물에타서', '물을', '뭔가', '믿고', '바로', '받아서', '받았습니다', '배송',
#        '배송도', '배송빠르고', '배송은', '배송이', '번창하세요', '벌써', '보고', '보니', '보다',
#        '봅니다', '부모님이', '비타민', '비해', '빠르게', '빠르고', '빠른', '빠른배송', '빠릅니다',
#        '빨라서', '빨라요', '사드렸는데', '사봤어요', '사서', '샀는데', '샀어요', '상큼', '상큼하고',
#        '상큼하니', '상큼해요', '상품', '새콤하니', '생각보다', '생각하고', '생수에', '섞어서', '선물로',
#        '속이', '수시로', '시원하게', '시원하고', '시원한', '시지', '시지도', '시지않고', '시켜봤어요',
#        '시켰어요', '신맛을', '신맛이', '싶어서', '싸게', '아니지만', '아주', '아주좋아요', '아직',
#        '아직은', '아침', '아침마다', '아침에', '않고', '않아', '않아서', '않아요', '약간', '양이',
#        '엄마', '엄마가', '엄청', '없고', '없어서', '없어요', '없이', '없지만', '여기가', '여기저기',
#        '여름', '여름에', '여름이라', '열심히', '예정입니다', '오늘', '오자마자', '완전', '왔어요',
#        '왠지', '요즘', '우선', '운동할때', '운동후', '위해', '유기농', '유기농이라', '유통기한',
#        '유통기한도', '의사', '이거', '이렇게', '일단', '입니다', '있고', '있네요', '있는', '있는데',
#        '있습니다', '있어', '있어서', '있어요', '있으면', '자주', '잘먹겠습니다', '잘먹고', '잘먹고있어요',
#        '잘먹을게요', '잘받았습니다', '잘받았어요', '재구매', '재구매늘', '재구매만족합니다', '재구매빠른배송',
#        '재구매입니다', '재구매할께요', '재구매합니다', '재구매해서', '재구매했습니다', '재구매했어요', '저는',
#        '저도', '저렴하게', '저렴하고', '저렴한', '저렴해서', '저렴히', '적당히', '정말', '제가',
#        '제일', '제품', '제품도', '제품은', '제품인데', '제품입니다', '조금', '조아요', '좀더',
#        '좋겠네요', '좋겠어요', '좋고', '좋네요', '좋다', '좋다고', '좋다고해서', '좋다길래', '좋다니',
#        '좋다하니', '좋다하여', '좋다해서', '좋더라구요', '좋습니다', '좋아', '좋아서', '좋아요',
#        '좋아지는', '좋아하네요', '좋아하세요', '좋아하시네요', '좋아해서', '좋았습니다', '좋았어요',
#        '좋으네요', '좋으면', '좋은', '좋은거', '좋은거같아요', '좋은것', '좋은데', '좋을', '좋을것',
#        '주문', '주문할게요', '주문할께요', '주문합니다', '주문해', '주문해달라고', '주문해서', '주문했는데',
#        '주문했습니다', '주문했어요', '지인이', '직접', '진짜', '진하고', '짜서', '챙겨', '챙겨먹고',
#        '챙기고', '처음', '처음엔', '최고', '최고입니다', '추가', '추가로', '추천으로', '추천합니다',
#        '친구', '친구가', '타먹고', '타먹기', '타먹으니', '타서', '탄산수', '탄산수에', '텀블러에',
#        '파세요', '편리하게', '편리하고', '편리합니다', '편리해요', '편하게', '편하고', '편하네요',
#        '편합니다', '편해서', '편해요', '평소에', '포장', '포장도', '포장되어', '피부가', '피부도',
#        '피부에', '하고', '하나', '하나씩', '하네요', '하니', '하려고', '하루', '하루에', '하셔서',
#        '하시네요', '하지만', '한개씩', '한달사용기맛있어요', '한달사용기매일', '한달사용기먹기', '한달사용기몸에',
#        '한달사용기잘', '한달사용기좋아요', '한번', '한잔', '한잔씩', '한포', '한포씩', '합니다', '항상',
#        '해서', '해요', '했네요', '했는데', '했습니다', '했어요', '홀베리', '홈쇼핑', '홈쇼핑보다',
#        '홈쇼핑에서', '확실히', '효과', '효과가', '효과는', '효과를', '훨씬', '휴대하기', '휴대하기도',
#        '희석해서', '힘들었는데'], dtype=object)

# %%
dtm.sum(axis=0)
# Out:
# matrix([[  6,   6,   6,   6,   6,   8,  32,   7,   6,  14,  19,  12,   7,
#           38,   5,  18,  39,  33,  18, 121,   5,   5,   6,   7,   7,  16,
#           14,  74,   8,  18,   9,  21,   6,  23,   8,  23,  35,  53,  11,
#            5,   7,  13,   5,   8,  21,  35,   9,   6,  15,   6,  13,  18,
#           22,  54,   7,   6,   6,  16,   7,  34,   7,  12,  10,   6,  18,
#           10,   7,   6,   5,  14,   6,   6,   5,   6, 160,   6, 123,   6,
#           14,  13,   7,   6,   7,  27,  19,  16,   8,   7,  13,   6,   5,
#            6,  14,   6,  13,   8,   9,  17,   9,   6,  14,   9,  10,   7,
#            5,   6,  24,   7,   8,   9,   5,  17,  60,   6,   6,  50,  26,
#            7,  10,  23,  12,  62,  10,  18,   9,  15,   7,  74,   6,  26,
#            7,  13,  27,   7,  26,  11,   7,   6,  17,   6,  59,   6,  93,
#            8,   7,   9, 106,   8,  62,  59,   6,  20,  23,  17,   7,   8,
#           93,  12,   9,  50,   5,   7,  15, 161,   9,  15,  41, 107,   9,
#           26,   5,  15,   6,  19,   6,  21,   7,   6,   5,   6,  10,  17,
#           16,   7,  37,  18,  12,  10,   7,   6,   8,   9,   7,   9,   8,
#           32,  19,   5,   5,  49,   6,  12,   8,  48,  25,  12,   9,  15,
#           22,   7,   9,  10,   9,  63,   7,  26,   9, 107,  14,  25,   6,
#           36,  11,   7,  28,  82,  73,  25,   6,  23,  11,   8,   8,   7,
#           15,   6,  14,  14,   7,  12,  92,  32,  36,   8,   9,  10,   6,
#            6,  13,  22,  19,   8,  22,  18,   6,  12,   9,  30,  10,  28,
#            6,  12,  10,   8,  33,   9,  10,  17,   6,   8,   6,   8,   5,
#           14,   6,  15,   8,  54,   6,  23,   8,  18,  15,  19,  33,  11,
#           11,  15,   9,   6,  10,  26,  10,   9,   7,   6,   6,  13,  12,
#           10,   8,  18,   5,  22,   6,   6,   5,   5,   8,   6,  51,   5,
#            8,   6,  21,  11,  12,  10,  14,   6,  11,  12,  14,  14,  13,
#           13,  12,  17,  82,  30,  45, 129,   5,  22,  13,  14,  17,   6,
#           32,   7,  47,   8,   9,   8,   8,   6,  10,   9,   8,   9,  18,
#           13,  32,   7,  13,  11,   5,   6,  27,  13,  10,  24,   6,   7,
#            6,  12,  17,  36,   8,  11,  16,  73,  79,   5,  56,  24,   8,
#           13,  12,   7,  20,   5,  99,  10,  25, 526,   7,  11,   9,   9,
#            6,   8,   6,  17,   7,  30,  13,   8,   7,   9,   5,   5,  12,
#            7,   6,   6,   7,   6,  16,  10,  10,  41,   6,  11,  12,   6,
#           13,  11,   8,   6,  19,   8,   8,   6,   6,   5,   6,  19,   6,
#            6,   5,  10,   8,  95,   6,  28,   9,   6,   8,  11,   8,   8,
#           36,  65,   8,  13,  24,  29,   5,  23,  18,   7,  11,   8,   8,
#           16,  10,  18,  16,  12,   5,  20,  33,   6,   5,  10,   6,   7,
#           10,   6,   6,   8,   7,  19,  13,   9,  25,  27,  42,  25,  73,
#            9,   6,  10,   9,  12,  10,   6,  12,  14,  10,  19,  17,  11,
#            7,   9,  12,  10,  31,   7]])

# %%
word_count = pd.DataFrame({
    '단어': cv.get_feature_names_out(),
    '빈도': dtm.sum(axis=0).flat
})

# %%
df_sorted = word_count.sort_values(by='빈도', ascending=False)

# %%
df_sorted.to_excel(r'..\data\홀베리_word_count.xlsx')
